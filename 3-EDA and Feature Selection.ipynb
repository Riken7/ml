# %% [markdown]
# ## Import Dataset & Analyse

# %%
import pandas as pd

# Import the dataset
path = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
headers = ["symboling", "normalized-losses", "make", "fuel-type", "aspiration", "num-of-doors", 
           "body-style", "drive-wheels", "engine-location", "wheel-base", "length", "width", 
           "height", "curb-weight", "engine-type", "num-of-cylinders", "engine-size", 
           "fuel-system", "bore", "stroke", "compression-ratio", "horsepower", "peak-rpm", 
           "city-mpg", "highway-mpg", "price"]

df = pd.read_csv(path, names=headers, na_values=["?"])
df.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
# Displaying the Data Columns with their types and Non-Null Count
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
# Displaying Basic Statistics of all the Attributes/Columns
df.describe(include="all")
# Out:
#          symboling  normalized-losses    make fuel-type aspiration  \
# count   205.000000         164.000000     205       205        205
# unique         NaN                NaN      22         2          2
# top            NaN                NaN  toyota       gas        std
# freq           NaN                NaN      32       185        168
# mean      0.834146         122.000000     NaN       NaN        NaN
# std       1.245307          35.442168     NaN       NaN        NaN
# min      -2.000000          65.000000     NaN       NaN        NaN
# 25%       0.000000          94.000000     NaN       NaN        NaN
# 50%       1.000000         115.000000     NaN       NaN        NaN
# 75%       2.000000         150.000000     NaN       NaN        NaN
# max       3.000000         256.000000     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           203        205          205             205  205.000000  ...
# ...

# %%
# Checking for the Null Values
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# ## Step-2: Data Cleaning & Handling Missing Values

# %%
# Checking the Attributes with the Outliers

import numpy as np

outliers = []

for feature in df.select_dtypes(include=np.number).columns:
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - (1.5 * IQR)
    upper_bound = Q3 + (1.5 * IQR)
    
    if df[(df[feature] < lower_bound) | (df[feature] > upper_bound)].any(axis=None):
        outliers.append(feature)

print("Attributes with outliers:", outliers)
# Out:
# Attributes with outliers: ['normalized-losses', 'wheel-base', 'length', 'width', 'engine-size', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %% [markdown]
# ### Handling Missing Values/Outliers with different Methods:
#
# - **'normalized-losses'**: With 41 missing values, the mean is used to fill these, given the relatively larger proportion.
# - **'num-of-doors'**: Only 2 missing values, so mode is used to fill this categorical column.
# - **'bore'**: Backward fill is applied since it might follow a trend.
# - **'stroke'**: Mean is used for imputation as the number of missing values is small.
# - **'horsepower'**: Median is used due to potential skewness in the data.
# - **'peak-rpm'**: Mean is used due to the small proportion of missing values.
# - **'price'**: Median is chosen as it is likely skewed and is an important target variable.

# %%
# Handling Missing Values
# 1. Replace missing values in 'normalized-losses' (41 missing) with the mean, since it's a significant proportion of the dataset.
df["normalized-losses"] = df["normalized-losses"].fillna(df["normalized-losses"].mean())

# 2. Replace missing values in 'num-of-doors' (2 missing) with the mode, as it's a categorical variable and only 2 missing values.
df["num-of-doors"] = df["num-of-doors"].fillna(df["num-of-doors"].mode()[0])

# 3. Replace missing values in 'bore' (4 missing) using backward fill, since it may have an increasing trend or sequence.
df["bore"] = df["bore"].bfill()

# 4. Replace missing values in 'stroke' (4 missing) using the mean, assuming it's normally distributed and the missing proportion is small.
df["stroke"] = df["stroke"].fillna(df["stroke"].mean())

# 5. Replace missing values in 'horsepower' (2 missing) using the median, as the data might be skewed.
df["horsepower"] = df["horsepower"].fillna(df["horsepower"].median())

# 6. Replace missing values in 'peak-rpm' (2 missing) using the mean, since the missing proportion is very small.
df["peak-rpm"] = df["peak-rpm"].fillna(df["peak-rpm"].mean())

# 7. Replace missing values in 'price' (4 missing) using the median, as it's likely skewed and is a crucial variable.
df["price"] = df["price"].fillna(df["price"].median())

# Verifying that no missing values remain
print("Missing values after handling:\n", df.isnull().sum())
# Out:
# Missing values after handling:
#  symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# Checking the Types of Attributes once finally after Handling Missing Values
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# ## Differentiating Numerical and Categorical Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bifurcate the data into numerical and categorical attributes
numerical_features = df.select_dtypes(include=np.number).columns.tolist()
categorical_features = df.select_dtypes(include='object').columns.tolist()

print("Numerical Attributes:", numerical_features)
print("Categorical Attributes:", categorical_features)
# Out:
# Numerical Attributes: ['symboling', 'normalized-losses', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-size', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
# Categorical Attributes: ['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'engine-type', 'num-of-cylinders', 'fuel-system']

# %% [markdown]
# ## Regplot

# %%
# Draw regplot between each continuous attribute and price
for feature in numerical_features:
    if feature != 'price':  # Skip the price column itself
        plt.figure(figsize=(8, 5))
        sns.regplot(x=df['price'], y=df[feature], scatter_kws={'alpha':0.5})
        plt.title(f'Regplot of {feature} vs. Price')
        plt.show()

# %% [markdown]
# ## Analysis from Visualization
#
# ## Regplot Analysis:
# Important and Considerable Attributes based on the relationship with price:
# - **Wheel-Base**
# - **Length**
# - **Width**
# - **Curb-Weight**
# - **Engine-Size**
# - **Bore**
# - **Horsepower**
# - **City-mpg**
# - **Highway-mpg**
#
# These attributes show a significant relationship with the price, indicating that they are important for predicting the price of the vehicles.

# %% [markdown]
# ## Boxplot

# %%
# Draw boxplot between each categorical attribute and price
for feature in categorical_features:
    plt.figure(figsize=(8, 5))
    sns.boxplot(x=df[feature], y=df['price'])
    plt.title(f'Boxplot of {feature} vs. Price')
    plt.show()

# %% [markdown]
# ## Boxplot Analysis:
# Important and Considerable Attributes based on the relationship with price:
# - **Aspiration**
# - **Body-Style**
# - **Drive-Wheels**
# - **Engine-Location**
# - **Engine-Type**
# - **Num-of-Cylinders**
# - **Fuel-System**
#
# These categorical attributes show distinct price ranges across different categories, suggesting they are important factors in determining the price of the vehicles.
